# %%
import sympy as sp
# x^2020 + 3*x^3-1
x = sp.Symbol('x')
fx= x**2020 + 3*x**3-1
fx
# Out:
# x**2020 + 3*x**3 - 1

# %%
sp.diff(fx, x)
# Out:
# 2020*x**2019 + 9*x**2

# %%
gx = x/(x+1)
gx
# Out:
# x/(x + 1)

# %%
print("g'(x)= ",sp.simplify(sp.diff(gx,x)))
# Out:
# g'(x)=  (x + 1)**(-2)

# %%
fx = sp.exp(x)/x
sp.diff(fx,x)
# Out:
# exp(x)/x - exp(x)/x**2

# %%
gx = 3*sp.log(x,2) - x*sp.log(x)
gx
print("g'(x)= ", sp.simplify(sp.diff(gx, x)))
# Out:
# g'(x)=  -log(x) - 1 + 3/(x*log(2))
